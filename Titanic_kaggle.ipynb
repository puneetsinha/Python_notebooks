# %%
import pandas as pd
import numpy as np
import os

# %%
titanicDf=pd.DataFrame.from_csv("D:\python_codes\datasets\\titanic\\train.csv")
#titanicDf.head()

# %%
print titanicDf.shape
titanicDf.dtypes

# %%
survivor=titanicDf.loc[titanicDf.Survived ==1]
survivor[['Age','Fare']].describe()

# %%
titanicDf.loc[(titanicDf.Sex=='female') & (titanicDf.Age > 30)]

# %%
titanicDf.Age.isnull().value_counts()

# %%
# %pylab inline
titanicDf.Age.hist(bins=20)

# %%
titanicDf.Age.describe()

# %%
titanicDf.Age.fillna(mean(titanicDf.Age))

# %%
pd.concat([titanicDf.describe(),titanicDf.quantile(np.arange(0.8,1.0,0.5))])

#titanicDf.describe()
#+ titanicDf.quantile([0.8,0.9])
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
# 0.8      1.000000    3.000000   41.000000    1.000000    1.000000   39.687500

# %%
# %pylab inline
pd.scatter_matrix(titanicDf,figsize=(16,10));
# Out:
# Populating the interactive namespace from numpy and matplotlib
