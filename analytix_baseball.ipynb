# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
baseballDt=pd.DataFrame.from_csv("D:\python_codes\datasets\\baseball\\baseball.csv")

# %%
print "the shape of the Dataset is " + str(baseballDt.shape)
print baseballDt.dtypes
# Out:
# the shape of the Dataset is (21699, 21)
# year       int64
# stint      int64
# team      object
# lg        object
# g          int64
# ab         int64
# r          int64
# h          int64
# X2b        int64
# X3b        int64
# hr         int64
# rbi      float64
# sb       float64
# cs       float64
# bb         int64
# so       float64
# ibb      float64
# hbp      float64
# sh       float64
# sf       float64
# gidp     float64
# dtype: object

# %%
names=baseballDt.columns.tolist()
baseballDt[names].isnull().apply(np.sum)
# Out:
# year        0
# stint       0
# team        0
# lg         65
# g           0
# ab          0
# r           0
# h           0
# X2b         0
# X3b         0
# hr          0
# rbi        12
# sb        250
# cs       4525
# bb          0
# so       1305
# ibb      7528
# hbp       377
# sh        960
# sf       7390
# gidp     5272
# dtype: int64

# %%
baseballDt.describe().drop('count')
# Out:
#              year     stint           g          ab           r           h  \
# mean  1961.067791  1.092723   72.817641  225.404903   31.780497   61.756901
# std     33.081972  0.309424   51.645925  215.895195   35.518542   64.065232
# min   1871.000000  1.000000    0.000000    0.000000    0.000000    0.000000
# 25%   1937.000000  1.000000   29.000000   25.000000    2.000000    4.000000
# 50%   1970.000000  1.000000   59.000000  131.000000   15.000000   32.000000
# 75%   1988.000000  1.000000  125.000000  435.000000   58.000000  119.000000
# max   2007.000000  4.000000  165.000000  705.000000  177.000000  257.000000
#
#             X2b        X3b         hr         rbi          sb         cs  \
# mean  10.452417   2.194064   5.234204   29.586573    5.168353   2.099744
# std   11.756606   3.469365   8.783342   33.835287   10.487860   3.645585
# min    0.000000   0.000000   0.000000    0.000000    0.000000   0.000000
# ...

# %%
dir(pd.core.groupby.DataFrameGroupBy)
# Out:
# ['__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__format__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__hash__',
#  '__init__',
#  '__iter__',
#  '__len__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_aggregate_generic',
#  '_aggregate_item_by_item',
#  '_aggregate_multiple_funcs',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_apply_whitelist',
#  '_block_agg_axis',
#  '_choose_path',
#  '_concat_objects',
#  '_constructor',
#  '_cumcount_array',
#  '_cython_agg_blocks',
#  '_cython_agg_general',
#  '_cython_transform',
#  '_decide_output_index',
#  '_def_str',
#  '_define_paths',
#  '_dir_additions',
#  '_dir_deletions',
#  '_get_data_to_aggregate',
#  '_get_index',
#  '_get_indices',
#  '_group_selection',
#  '_index_with_as_index',
# ...

# %%
baseballDt.head()
baseballDt.groupby('lg').size()
# Out:
# lg
# AA      171
# AL    10007
# FL       37
# NL    11378
# PL       32
# UA        9
# dtype: int64

# %%
    print baseballDt[col].value_counts
